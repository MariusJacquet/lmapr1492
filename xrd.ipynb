# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.analysis.diffraction.xrd import XRDCalculator

# %%
with MPRester("eydjkyvaohvx0D8I") as m:
    structure = m.get_structure_by_material_id("mp-30460")

# %%
xrd = XRDCalculator("CuKa1")
pattern = xrd.get_pattern(structure)

# %% [markdown]
# # Calcul des 3 premiers pics du diffractogramme

# %%
i = 0
while i < 3:
    print("Pic du diffractogramme n°",i+1,"\n",
         "Angle 2Θ entre les 2 rayons :", pattern.x[i],"\n",
         "Intensité du premier pic :", pattern.y[i],"\n",
         "Indices hkl associés :", pattern.hkls[i],"\n",
         "Distance associée :", pattern.d_hkls[i],"\n")
    i+=1
# Out:
# Pic du diffractogramme n° 1
#  Angle 2Θ entre les 2 rayons : 23.69808625296471
#  Intensité du premier pic : 31.726290041732867
#  Indices hkl associés : [{'hkl': (1, 1, 1), 'multiplicity': 2}, {'hkl': (1, 0, 0), 'multiplicity': 6}]
#  Distance associée : 3.7513541586692845
#
# Pic du diffractogramme n° 2
#  Angle 2Θ entre les 2 rayons : 27.430780939110775
#  Intensité du premier pic : 52.034237420571124
#  Indices hkl associés : [{'hkl': (1, 1, 0), 'multiplicity': 6}]
#  Distance associée : 3.248768
#
# Pic du diffractogramme n° 3
#  Angle 2Θ entre les 2 rayons : 39.18263113009672
#  Intensité du premier pic : 100.0
#  Indices hkl associés : [{'hkl': (2, 1, 1), 'multiplicity': 6}, {'hkl': (1, 0, -1), 'multiplicity': 6}]
#  Distance associée : 2.2972258833018575

# %% [markdown]
# # Diffractogramme des 3 premiers pics

# %%
xrd.show_plot(structure, two_theta_range=(0,45))
